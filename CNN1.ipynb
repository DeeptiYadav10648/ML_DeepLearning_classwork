# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Flatten, Conv2D, MaxPooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential 
#import optimizer and loss function
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# what is the use of rescaling and data augmentation in image data generator
# Rescaling and data augmentation are techniques used in image data preprocessing to improve the performance of machine learning models
# Rescaling is the process of normalizing pixel values to a specific range, typically between 0 and 1. This helps to standardize the input data and can improve the convergence of the model during training.
# Data augmentation is the process of artificially increasing the size of the training dataset by applying various transformations to the images, such as rotation, flipping, zooming, and shifting.
#  This helps to prevent overfitting and improve the generalization of the model by providing it with more diverse training examples.

# %%
train_generator = ImageDataGenerator(rescale=1./255, rotation_range=20, width_shift_range=0.2, height_shift_range=0.2, horizontal_flip=True)
train_data = train_generator.flow_from_directory('C:\\Users\\Acer\\academics\\deep_learning\\Datasets\\brain_tumour\\Training', target_size=(256, 256), batch_size=32, class_mode='categorical')
# Out:
# Found 5600 images belonging to 4 classes.

# %%
test_generator = ImageDataGenerator(rescale=1./255)
test_data = test_generator.flow_from_directory('C:\\Users\\Acer\\academics\\deep_learning\\Datasets\\brain_tumour\\Testing', target_size=(256, 256), batch_size=32, class_mode='categorical')
# Out:
# Found 1600 images belonging to 4 classes.

# %%
#@title Plotting an images
import math
# Function to plot images
def plot_images(images, labels):
    num_images = images.shape[0]
    num_rows = int(math.ceil(num_images / 4))
    fig, axes = plt.subplots(num_rows, 4, figsize=(12, 3 * num_rows))
    for i in range(num_images):
        row = i // 4
        col = i % 4
        axes[row, col].imshow(images[i])
        axes[row, col].set_title(f"Class: {np.argmax(labels[i])}")
        axes[row, col].axis('off')
    plt.tight_layout()
    plt.show()


# Get a batch of training images and labels
train_images, train_labels = next(train_data)

# Get a batch of testing images and labels
test_images, test_labels = next(test_data)

# Plot a few images from the training and testing data
import matplotlib.pyplot as plt
import numpy as np
plot_images(train_images, train_labels)
plot_images(test_images, test_labels)

# %%
#CNN 
#conv---pooling---conv---pooling---flatten---dense---output
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(16, activation='relu'),
    Dropout(0.5),
    Dense(8, activation='relu'),
    Dense(4, activation='softmax')
])
# Out:
# c:\Users\Acer\academics\deep_learning\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#optimizers and loss function
model_compile = model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
History = model.fit(train_data, epochs=50, validation_data=test_data, verbose=1)
# Out:
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 320s 2s/step - accuracy: 0.3268 - loss: 1.3553 - val_accuracy: 0.4725 - val_loss: 1.2427
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 310s 2s/step - accuracy: 0.3770 - loss: 1.2676 - val_accuracy: 0.4819 - val_loss: 1.2999
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 317s 2s/step - accuracy: 0.3946 - loss: 1.2565 - val_accuracy: 0.4681 - val_loss: 1.3236
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.3980 - loss: 1.2448 - val_accuracy: 0.5537 - val_loss: 1.2262
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 0.4075 - loss: 1.2379 - val_accuracy: 0.5781 - val_loss: 1.2584
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.4230 - loss: 1.2243 - val_accuracy: 0.5900 - val_loss: 1.3762
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - accuracy: 0.4241 - loss: 1.2212 - val_accuracy: 0.6075 - val_loss: 1.2989
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.4266 - loss: 1.2196 - val_accuracy: 0.5775 - val_loss: 1.3395
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 178s 1s/step - accuracy: 0.4309 - loss: 1.2163 - val_accuracy: 0.6119 - val_loss: 1.3492
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - accuracy: 0.4316 - loss: 1.2089 - val_accuracy: 0.6175 - val_loss: 1.3456
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.4339 - loss: 1.2059 - val_accuracy: 0.5763 - val_loss: 1.5439
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.4437 - loss: 1.1977 - val_accuracy: 0.6031 - val_loss: 1.4018
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.4387 - loss: 1.1934 - val_accuracy: 0.5481 - val_loss: 1.2953
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.4304 - loss: 1.2075 - val_accuracy: 0.6069 - val_loss: 1.3092
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.4309 - loss: 1.2112 - val_accuracy: 0.6069 - val_loss: 1.3701
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.4386 - loss: 1.1892 - val_accuracy: 0.6200 - val_loss: 1.3584
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.4432 - loss: 1.1867 - val_accuracy: 0.6100 - val_loss: 1.4075
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.4341 - loss: 1.1971 - val_accuracy: 0.5938 - val_loss: 1.5162
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.4368 - loss: 1.1953 - val_accuracy: 0.6075 - val_loss: 1.4627
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.4407 - loss: 1.1946 - val_accuracy: 0.5337 - val_loss: 1.3444
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.4375 - loss: 1.1938 - val_accuracy: 0.5994 - val_loss: 1.4683
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.4346 - loss: 1.2025 - val_accuracy: 0.5238 - val_loss: 1.3311
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.4452 - loss: 1.1806 - val_accuracy: 0.5750 - val_loss: 1.5067
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.4379 - loss: 1.1981 - val_accuracy: 0.5944 - val_loss: 1.3985
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 193s 1s/step - accuracy: 0.4437 - loss: 1.1749 - val_accuracy: 0.5994 - val_loss: 1.3996
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.4571 - loss: 1.1631 - val_accuracy: 0.5987 - val_loss: 1.3471
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - accuracy: 0.4437 - loss: 1.1777 - val_accuracy: 0.6069 - val_loss: 1.3534
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.4396 - loss: 1.1823 - val_accuracy: 0.6081 - val_loss: 1.4780
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 0.4425 - loss: 1.1815 - val_accuracy: 0.6194 - val_loss: 1.4258
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.4387 - loss: 1.1818 - val_accuracy: 0.5819 - val_loss: 1.5956
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.4473 - loss: 1.1735 - val_accuracy: 0.6019 - val_loss: 1.5456
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.4545 - loss: 1.1563 - val_accuracy: 0.6056 - val_loss: 1.4194
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.4427 - loss: 1.1750 - val_accuracy: 0.6106 - val_loss: 1.4523
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.4504 - loss: 1.1681 - val_accuracy: 0.6131 - val_loss: 1.4778
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 0.4518 - loss: 1.1652 - val_accuracy: 0.5719 - val_loss: 1.6099
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - accuracy: 0.4437 - loss: 1.1758 - val_accuracy: 0.5888 - val_loss: 1.5555
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 0.4430 - loss: 1.1779 - val_accuracy: 0.6019 - val_loss: 1.5545
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.4352 - loss: 1.1873 - val_accuracy: 0.5700 - val_loss: 1.6861
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.4432 - loss: 1.1714 - val_accuracy: 0.5850 - val_loss: 1.7486
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.4509 - loss: 1.1643 - val_accuracy: 0.5831 - val_loss: 1.6134
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 0.4500 - loss: 1.1671 - val_accuracy: 0.5819 - val_loss: 1.4879
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.4520 - loss: 1.1695 - val_accuracy: 0.5738 - val_loss: 1.6030
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.4468 - loss: 1.1787 - val_accuracy: 0.6012 - val_loss: 1.4606
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.4545 - loss: 1.1666 - val_accuracy: 0.6069 - val_loss: 1.3803
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.4529 - loss: 1.1580 - val_accuracy: 0.6125 - val_loss: 1.4135
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.4520 - loss: 1.1607 - val_accuracy: 0.6225 - val_loss: 1.4091
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.4493 - loss: 1.1697 - val_accuracy: 0.6187 - val_loss: 1.3990
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.4523 - loss: 1.1591 - val_accuracy: 0.5838 - val_loss: 1.5362
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.4434 - loss: 1.1718 - val_accuracy: 0.6200 - val_loss: 1.3795
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 0.4473 - loss: 1.1686 - val_accuracy: 0.5919 - val_loss: 1.4662

# %%
#download the model batch file
# Ensure the model is defined by running the cell where it is created (CELL INDEX: 5) before executing this cell
model.save("brain_tumor_model1.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
loss, acc = model.evaluate(test_data)
print("Accuracy:", acc)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 178ms/step - accuracy: 0.8919 - loss: 1.8602
# Accuracy: 0.8918750286102295

# %%
#load the model
from tensorflow.keras.models import load_model
model = load_model(r"C:\Users\Acer\academics\deep_learning\brain_tumor_model1.h5")  #model path
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
#list of classes  from the training data
class_names = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
print("Class names:", class_names)
# Out:
# Class names: ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']

# %%
from tensorflow.keras.preprocessing import image
import numpy as np


img = image.load_img(r"C:\Users\Acer\academics\deep_learning\Datasets\brain_tumour\Testing\meningioma\Te-aug-me_5.jpg", target_size=(256, 256))
img_array = image.img_to_array(img) / 255.0   #image to array and rescaling     
img_array = np.expand_dims(img_array, axis=0) # Add batch dimension  because the model expects a batch of images as input, even if it's just one image. By adding an extra dimension, we create a batch of size 1, which allows us to pass the image through the model for prediction.
    
predictions = model.predict(img_array)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step

# %%
label = class_names[np.argmax(predictions)]
print("Predicted label:", label)
# Out:
# Predicted label: meningioma_tumor
